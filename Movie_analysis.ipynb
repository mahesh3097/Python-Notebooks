# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Documents/stock_data.csv", header = 1, na_values = {
    'eps' : ["not available","n.a."], 
    'revenue': ["not available","n.a.", "-1"],
    'price' : ["not available","n.a."],
    'people' : ["not available","n.a."]
    
})

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0          larry
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3     RIL    NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
a = np.array([3]*4 , dtype='int32')

# %%
a
# Out:
# array([3, 3, 3, 3], dtype=int32)

# %%
df = pd.read_csv('http://bit.ly/imdbratings')

# %%
df = df[df['star_rating'] >= 8]

# %%
df = pd.to_numeric(df['star_rating'])

# %%
type(df['star_rating'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.rename(columns = {'star_rating' : 'IMDB Rating'}, inplace = True)

# %%
movies.drop(movies.index[0:9], axis=0)
# Out:
#      IMDB Rating                                              title  \
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 16           8.7                    One Flew Over the Cuckoo's Nest
# 17           8.7                                      Seven Samurai
# 18           8.7                                         Goodfellas
# 19           8.7                                          Star Wars
# 20           8.7                                         The Matrix
# 21           8.7                                        City of God
# ...

# %% [markdown]
# movies

# %%
movies.head()
# Out:
#    IMDB Rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
type(movies[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-180ddb02a85f> in <module>
# ----> 1 type(movies[1])
#
# ...

# %%
movies.iloc[1:2, 0]
# Out:
# 1    9.2
# Name: IMDB Rating, dtype: float64

# %%
type(movies['duration'])
# Out:
# pandas.core.series.Series

# %%
movies.loc[1:5, 'IMDB Rating']
# Out:
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# 5    8.9
# Name: IMDB Rating, dtype: float64

# %%
movies.head()
# Out:
#    IMDB Rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#setting movie name as index
movies.set_index('title').head(25)
# Out:
#                                                    IMDB Rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# ...

# %%
df = movies.groupby('genre').mean()

# %%
# %matplotlib inline

# %%
movies.groupby('genre').mean().plot(kind='bar')

# %%
#Highest rated genre on average 
df.sort_values('IMDB Rating', ascending = False)
# Out:
#            IMDB Rating    duration
# genre
# Western       8.255556  136.666667
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Mystery       7.975000  115.625000
# Adventure     7.933333  134.840000
# Sci-Fi        7.920000  109.000000
# Crime         7.916935  122.298387
# Animation     7.914516   96.596774
# Drama         7.902518  126.539568
# Action        7.884559  126.485294
# Biography     7.862338  131.844156
# Family        7.850000  107.500000
# Comedy        7.822436  107.602564
# Horror        7.806897  102.517241
# Fantasy       7.700000  112.000000
# Thriller      7.680000  114.200000

# %%
#average rating grouped by rating 
movies.groupby('genre').mean().sort_values('IMDB Rating', ascending = False)
# Out:
#            IMDB Rating    duration
# genre
# Western       8.255556  136.666667
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Mystery       7.975000  115.625000
# Adventure     7.933333  134.840000
# Sci-Fi        7.920000  109.000000
# Crime         7.916935  122.298387
# Animation     7.914516   96.596774
# Drama         7.902518  126.539568
# Action        7.884559  126.485294
# Biography     7.862338  131.844156
# Family        7.850000  107.500000
# Comedy        7.822436  107.602564
# Horror        7.806897  102.517241
# Fantasy       7.700000  112.000000
# Thriller      7.680000  114.200000

# %%
movies['Genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: Genre, dtype: int64

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.head(3)
# Out:
#    IMDB Rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
#replace column title to Movie Name
movies.rename(columns = {'title':'Movie Name', 'actors_list':'Cast', 'content_rating': 'Rating', 'genre':'Genre' }, inplace =True)

# %%
#remove '[]' and u from cast 
movies['Cast'] = movies['Cast'].str.replace('u\'','').str.replace('\'','').str.replace(']','')

# %% [markdown]
# movies['genre'].value_counts()

# %%
movies['Rating'].isna() #gives series with false abnd true
movies['Rating'].isna().any() #if even single field is missing
movies['Rating'].isna().value_counts() # number of true and false
movies[movies['Rating'].isna()]  #data frame of missing values
# Out:
#      IMDB Rating                          Movie Name Rating      Genre  \
# 187          8.2  Butch Cassidy and the Sundance Kid    NaN  Biography
# 649          7.7                   Where Eagles Dare    NaN     Action
# 936          7.4                           True Grit    NaN  Adventure
#
#      duration                                         Cast
# 187       110  Paul Newman, Robert Redford, Katharine Ross
# 649       158     Richard Burton, Clint Eastwood, Mary Ure
# 936       128         John Wayne, Kim Darby, Glen Campbell

# %%
#add column 
movies['good/bad'] = 'GOOD'

# %% [markdown]
# movies

# %%
#delete column
del movies['good/bad']

# %%
movies.head(3)
# Out:
#    IMDB Rating                Movie Name Rating  Genre  duration  \
# 0          9.3  The Shawshank Redemption      R  Crime       142
# 1          9.2             The Godfather      R  Crime       175
# 2          9.1    The Godfather: Part II      R  Crime       200
#
#                                         Cast
# 0   [Tim Robbins, Morgan Freeman, Bob Gunton
# 1      [Marlon Brando, Al Pacino, James Caan
# 2  [Al Pacino, Robert De Niro, Robert Duvall

# %%
genre_group = movies.groupby('Genre')

# %%
for genre, genre_df in genre_group:
   # print(genre)
   
    #print(genre_df)
    genre_df.shape

# %% [markdown]
# movies

# %%
for genre, genre_df in genre_group:
    print(genre)
   
    #print(genre_df)
    print(genre_df.shape)
# Out:
# Action
# (136, 6)
# Adventure
# (75, 6)
# Animation
# (62, 6)
# Biography
# (77, 6)
# Comedy
# (156, 6)
# Crime
# (124, 6)
# Drama
# (278, 6)
# Family
# (2, 6)
# Fantasy
# (1, 6)
# Film-Noir
# (3, 6)
# History
# (1, 6)
# Horror
# (29, 6)
# Mystery
# (16, 6)
# Sci-Fi
# (5, 6)
# Thriller
# (5, 6)
# Western
# (9, 6)
